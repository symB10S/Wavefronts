# %%
import Wavefront_Generation as WG
import Wavefront_Plotting as WP
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib widget

# %% [markdown]
# # Plotting Time Linked Data

# %%
interface = WG.Full_Cycle(L_time=23,C_time =24,L_impedance = 350, show_about=False)

# %% [markdown]
# we start first with the simple time plot of the interconnect

# %%
fig1,ax1 = plt.subplots()
WP.plot_time_interconnect(interface,ax1,'current capacitor',True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig_wave,ax_wave = plt.subplots()

WP.plot_time_wavefronts(interface,ax_wave,"voltage inductor",False, True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig_int_all, ax_int_all = WP.make_time_interconnect_all(interface)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig,ax = WP.make_time_wavefronts_all(interface,True,True)
WP.make_time_wavefronts_all(interface,False,True,ax=ax)

fig.suptitle('Comparison between accumulated time wavefront behaviour')

ax['VS'].set_title('Sending Voltage Wavefronts')
ax['VR'].set_title('Returning Voltage Wavefronts')
ax['IS'].set_title('Sending Current Wavefronts')
ax['IR'].set_title('Returning Current Wavefronts')

for ax_i in ax.values(): 
    ax_i.legend(['Inductor', 'Capacitor'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
len(interface.data_output_ordered.Wavefronts_Returning_Capacitor)
# Out:
# 1129
