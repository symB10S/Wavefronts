# %%
import Wavefront_Generation as WG
import Wavefront_Plotting as WP
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib widget

# %% [markdown]
# # Plotting Time Linked Data

# %%
interface = WG.Full_Cycle(L_time=8,C_time =13,L_impedance = 350, show_about=False)

# %% [markdown]
# we start first with the simple time plot of the interconnect

# %%
fig1,ax1 = plt.subplots()
WP.plot_time_interconnect(interface.data_output_ordered,ax1,'current capacitor',True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
