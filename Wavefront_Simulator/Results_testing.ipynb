# %%
from Wavefront_Generation import Full_Cycle
import Wavefront_Plotting as WP
import Wavefront_Interactive as WI
# %matplotlib widget

# %%
# inreface = Full_Cycle(L_impedance = '800',
#                       L_time = ' 2',
#                       C_time = '0.313',
#                       )
inreface = Full_Cycle(L_impedance = '800',
                      L_time = ' 134',
                      C_time = '174',
                      )
# Out:
# Information about this network :
#
#
# - The Inductor -
# Inductor Inductance Per Length :        53600
# Inductor Capacitance Per Length :       0.08375
# Inductor Length :                       1
# Inductor Total Inductance :             53600
# Inductor Total Capacitance :            0.08375
# Inductor Velocity :                     0.01492537313432835820895522388
# Inductor One Way Time Delay :           67
# Inductor Impedance :                    800
#
# - The Capacitor -
# Capacitor Inductance Per Length :       87
# Capacitor Capacitance Per Length :      87
# Capacitor Length :                      1
# Capacitor Total Inductance :            87
# Capacitor Total Capacitance :           87
# Capacitor Velocity :                    0.01149425287356321839080459770
# Capacitor One Way Time Delay :          87
# Capacitor Impedance :                   1
#
# - The Time -
# Number Periods :                        1
# ...

# %%
WI.spatial_interconnect_investigator_ui(inreface)
# Out:
# GridspecLayout(children=(Button(description='step backward', layout=Layout(grid_area='widget001', width='auto'…
# FloatSlider(value=0.0, layout=Layout(width='auto'), max=1000.0, step=1.0)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# WP.save_spatial_interconnect(inreface,save_name = "lots of waves")
# Out:
# 100%|██████████| 1800/1800 [46:03<00:00,  1.54s/it]
# Spatial video generation completed, video saved as lots of waves.mp4

# %%
WP.make_fanout_interconnect_all(inreface.data_output_multiplicative,padding=10)
# Out:
# (<Figure size 1000x800 with 8 Axes>,
#  {'VC': <AxesSubplot:label='VC', title={'center':'Capacitor Voltage at Interconnect'}, xlabel='L - axis ', ylabel='C - axis '>,
#   'VL': <AxesSubplot:label='VL', title={'center':'Inductor Voltage at Interconnect'}, xlabel='L - axis ', ylabel='C - axis '>,
#   'IC': <AxesSubplot:label='IC', title={'center':'Capacitor Current at Interconnect'}, xlabel='L - axis ', ylabel='C - axis '>,
#   'IL': <AxesSubplot:label='IL', title={'center':'Inductor Current at Interconnect'}, xlabel='L - axis ', ylabel='C - axis '>})
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
WI.interact_interconnect_time_and_fanout_path(inreface)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', layout=Layout(width='auto'), max=1000.0, step=1.…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
